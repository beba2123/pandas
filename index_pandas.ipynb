# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\hp pavilion\Downloads\world_population.csv") # we can use index_col = 0 for set index
# or we can use for set index  df.set_index('Country', inplace = True) the use of inplace is to set the index in the same dataframe

df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df2 = df.set_index('Continent').sort_values(by= 'Capital') # we can use sort_value(by='Rank', ascending= True) for sort the data
df2
# df.sort_values(by = ['Continent', 'Capital'], ascending = [True, True]) # we can use this for sort the data by multiple columns
# Out:
#            Rank CCA3               Country       Capital  2022 Population  \
# Continent
# Asia         97  ARE  United Arab Emirates     Abu Dhabi        9441129.0
# Africa        6  NGA               Nigeria         Abuja      218541212.0
# Africa       47  GHA                 Ghana         Accra       33475870.0
# Africa       12  ETH              Ethiopia   Addis Ababa      123379924.0
# Africa       34  DZA               Algeria       Algiers       44903225.0
# ...         ...  ...                   ...           ...              ...
# Africa       52  CIV           Ivory Coast  Yamoussoukro       28160542.0
# Africa       53  CMR              Cameroon       Yaounde       27914536.0
# Oceania     225  NRU                 Nauru         Yaren          12668.0
# Asia        140  ARM               Armenia       Yerevan        2780469.0
# Europe      130  HRV               Croatia        Zagreb        4030358.0
#
# ...

# %%
df2.iloc[4]
# Out:
# Rank                                   34
# CCA3                                  DZA
# Country                           Algeria
# Capital                           Algiers
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: Africa, dtype: object

# %%
df3 = df2.loc['Asia']
df3
# Out:
#            Rank CCA3               Country              Capital  \
# Continent
# Asia         97  ARE  United Arab Emirates            Abu Dhabi
# Asia         83  JOR                Jordan                Amman
# Asia         18  TUR                Turkey               Ankara
# Asia        111  TKM          Turkmenistan             Ashgabat
# Asia         35  IRQ                  Iraq              Baghdad
# Asia         91  AZE            Azerbaijan                 Baku
# Asia        175  BRN                Brunei  Bandar Seri Begawan
# Asia         20  THA              Thailand              Bangkok
# Asia          1  CHN                 China              Beijing
# Asia        119  LBN               Lebanon               Beirut
# Asia        110  KGZ            Kyrgyzstan              Bishkek
# Asia         61  LKA             Sri Lanka              Colombo
# Asia        167  MAC                 Macau    Concelho de Macau
# ...

# %%
df3.iloc[4]
# Out:
# Rank                                   35
# CCA3                                  IRQ
# Country                              Iraq
# Capital                           Baghdad
# 2022 Population                44496122.0
# 2020 Population                42556984.0
# 2015 Population                37757813.0
# 2010 Population                31264875.0
# 2000 Population                24628858.0
# 1990 Population                17658381.0
# 1980 Population                13653369.0
# 1970 Population                 9811347.0
# Area (km²)                       438317.0
# Density (per km²)                101.5158
# Growth Rate                        1.0221
# World Population Percentage          0.56
# Name: Asia, dtype: object

# %%
df4 = df.set_index(['Continent', 'Country']).sort_index( ascending = (True, False)) # we can use this for sort the data by multiple columns
df4
# Out:
#                               Rank CCA3       Capital  2022 Population  \
# Continent     Country
# Africa        Zimbabwe          74  ZWE        Harare       16320537.0
#               Zambia            63  ZMB        Lusaka       20017675.0
#               Western Sahara   172  ESH      El Aaiún         575986.0
#               Uganda            31  UGA       Kampala       47249585.0
#               Tunisia           79  TUN         Tunis       12356117.0
# ...                            ...  ...           ...              ...
# South America Colombia          28  COL        Bogota       51874024.0
#               Chile             65  CHL      Santiago       19603733.0
#               Brazil             7  BRA      Brasilia      215313498.0
#               Bolivia           80  BOL         Sucre       12224110.0
#               Argentina         33  ARG  Buenos Aires       45510318.0
#
#                               2020 Population  2015 Population  \
# Continent     Country
# ...

# %%
df4.swaplevel('Country', 'Continent') # it swap the index
# Out:
#                               Rank CCA3       Capital  2022 Population  \
# Country        Continent
# Zimbabwe       Africa           74  ZWE        Harare       16320537.0
# Zambia         Africa           63  ZMB        Lusaka       20017675.0
# Western Sahara Africa          172  ESH      El Aaiún         575986.0
# Uganda         Africa           31  UGA       Kampala       47249585.0
# Tunisia        Africa           79  TUN         Tunis       12356117.0
# ...                            ...  ...           ...              ...
# Colombia       South America    28  COL        Bogota       51874024.0
# Chile          South America    65  CHL      Santiago       19603733.0
# Brazil         South America     7  BRA      Brasilia      215313498.0
# Bolivia        South America    80  BOL         Sucre       12224110.0
# Argentina      South America    33  ARG  Buenos Aires       45510318.0
#
#                               2020 Population  2015 Population  \
# ...

# %%
df.sort_index()
pd.set_option('display.max_rows', 230)

# %%
df.loc['Africa', 'Algeria'] # to access the data in the multple index we use the loc method
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp pavilion\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Algeria'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[473], line 1
# ...

# %%
df.iloc[0]  # the iloc method is not efficient in the multiple index to access the right data that we want
# Out:
# index                                   0
# Rank                                   36
# CCA3                                  AFG
# Capital                             Kabul
# 2022 Population                41128771.0
# 2020 Population                38972230.0
# 2015 Population                33753499.0
# 2010 Population                28189672.0
# 2000 Population                19542982.0
# 1990 Population                10694796.0
# 1980 Population                12486631.0
# 1970 Population                10752971.0
# Area (km²)                       652230.0
# Density (per km²)                 63.0587
# Growth Rate                        1.0257
# World Population Percentage          0.52
# Name: (Asia, Afghanistan), dtype: object
