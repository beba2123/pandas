# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\hp pavilion\Downloads\tech_price.xlsx", index_col = [0, 1], header = [0, 1])
df
# Out:
#                    USD                 EUR
# company           open high low close open high low close
# 2023-01-01 Apple    89   26  68    69   37   56  11    25
#            Google   66   71  26    83   96   68  91    11
#            Amazon   12   43  97    75   25   25  90    43
# 2023-01-02 Apple    54   49  77    49   68   44  85    68
#            Google   84   92  55    90   51   50  59    68
#            Amazon   41   86  13    19   41   36  50    26
# 2023-01-03 Apple    67   47  46    70   41   62  72    49
#            Google   60   70  54    71   78   47  12    57
#            Amazon   71   15  47    53   86   44  68    33
# 2023-01-04 Apple    56   50  54    83   59   36  45    19
#            Google   36   77  27    94   62   13  66    90
#            Amazon   64   97  64    56   48   57  45    50
# 2023-01-05 Apple    34   45  60    84   24   49  63    54
#            Google   69   92  14    63   21   85  80    87
# ...

# %%
df.stack(level=1)  #stacking the data frame
# Out:
# C:\Users\hp pavilion\AppData\Local\Temp\ipykernel_62772\2165884288.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=1)  #stacking the data frame
#                            USD  EUR
#                   company
# 2023-01-01 Apple  close     69   25
#                   high      26   56
#                   low       68   11
#                   open      89   37
#            Google close     83   11
#                   high      71   68
#                   low       26   91
#                   open      66   96
#            Amazon close     75   43
#                   high      43   25
#                   low       97   90
#                   open      12   25
# 2023-01-02 Apple  close     49   68
#                   high      49   44
# ...

# %%
df.stack(level=0)  #stacking the data frame
# Out:
# C:\Users\hp pavilion\AppData\Local\Temp\ipykernel_62772\2008295142.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=0)  #stacking the data frame
# company                open  high  low  close
# 2023-01-01 Apple  EUR    37    56   11     25
#                   USD    89    26   68     69
#            Google EUR    96    68   91     11
#                   USD    66    71   26     83
#            Amazon EUR    25    25   90     43
#                   USD    12    43   97     75
# 2023-01-02 Apple  EUR    68    44   85     68
#                   USD    54    49   77     49
#            Google EUR    51    50   59     68
#                   USD    84    92   55     90
#            Amazon EUR    41    36   50     26
# ...
