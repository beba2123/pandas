# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\hp pavilion\Downloads\banking.csv")
df
# Out:
#        age           job   marital  education default  outstanding_balance  \
# 0       58    management   married   tertiary      no                 2143
# 1       44    technician    single  secondary      no                   29
# 2       33  entrepreneur   married  secondary      no                    2
# 3       47   blue-collar   married    unknown      no                 1506
# 4       33       unknown    single    unknown      no                    1
# ...    ...           ...       ...        ...     ...                  ...
# 45206   51    technician   married   tertiary      no                  825
# 45207   71       retired  divorced    primary      no                 1729
# 45208   72       retired   married  secondary      no                 5715
# 45209   57   blue-collar   married  secondary      no                  668
# 45210   37  entrepreneur   married  secondary      no                 2971
#
#       housing_loan personal_loan
# 0              yes            no
# ...

# %%
df2 = df.sort_values(by = 'age', ascending= True)
df2
# Out:
#        age      job   marital  education default  outstanding_balance  \
# 42954   18  student    single    unknown      no                  108
# 41273   18  student    single    unknown      no                    3
# 42146   18  student    single  secondary      no                  156
# 43637   18  student    single    unknown      no                  348
# 40736   18  student    single    primary      no                 1944
# ...    ...      ...       ...        ...     ...                  ...
# 44420   93  retired   married    unknown      no                  775
# 44262   93  retired   married    unknown      no                  775
# 31233   94  retired  divorced  secondary      no                 1234
# 41663   95  retired   married  secondary      no                    0
# 33699   95  retired  divorced    primary      no                 2282
#
#       housing_loan personal_loan
# 42954           no            no
# 41273           no            no
# ...

# %%
df_4 = df.groupby('marital')['age'].mean()
df_9  = df_4.reset_index()
df_9.rename(columns = {'age':'Total Age'}, inplace = True)
df_9
# df_9 = df_4.reset_index()
# df_9.rename(columns = {'age':'Total Age'}, inplace = True)
# df_9
# Out:
#     marital  Total Age
# 0  divorced  45.782984
# 1   married  43.408099
# 2    single  33.703440

# %%
df_avg = df.groupby('job')['age'].mean()
df_avg
# Out:
# job
# admin.           39.289886
# blue-collar      40.044081
# entrepreneur     42.190989
# housemaid        46.415323
# management       40.449567
# retired          61.626767
# self-employed    40.484484
# services         38.740250
# student          26.542644
# technician       39.314598
# unemployed       40.961627
# unknown          47.593750
# Name: age, dtype: float64

# %%
df_des = df.groupby('job').describe()
df_des
# Out:
#                   age                                                      \
#                 count       mean        std   min   25%   50%   75%   max
# job
# admin.         5171.0  39.289886   9.365483  20.0  32.0  38.0  46.0  75.0
# blue-collar    9732.0  40.044081   9.025888  20.0  33.0  39.0  47.0  75.0
# entrepreneur   1487.0  42.190989   9.114486  21.0  35.0  41.0  49.0  84.0
# housemaid      1240.0  46.415323  10.477275  22.0  38.0  47.0  55.0  83.0
# management     9458.0  40.449567   9.383415  21.0  33.0  38.0  48.0  81.0
# retired        2264.0  61.626767   9.535329  24.0  56.0  59.0  67.0  95.0
# self-employed  1579.0  40.484484   9.656075  22.0  33.0  39.0  48.0  76.0
# services       4154.0  38.740250   9.041371  20.0  32.0  37.0  46.0  69.0
# student         938.0  26.542644   4.842536  18.0  23.0  26.0  29.0  48.0
# technician     7597.0  39.314598   8.939944  21.0  32.0  37.0  46.0  71.0
# unemployed     1303.0  40.961627   9.777010  21.0  33.0  40.0  48.0  66.0
# ...

# %%
df.groupby('education').agg({'outstanding_balance': ['count', 'sum', 'mean' ]}) #so mostly agragate function used to perform multuple operations on a single column like mean, sum, count, etc
# Out:
#           outstanding_balance
#                         count       sum         mean
# education
# primary                  6851   8570258  1250.949934
# secondary               23202  26795544  1154.880786
# tertiary                13301  23388697  1758.416435
# unknown                  1857   2835183  1526.754443

# %%
df.groupby('education').agg(sum_balance = ('outstanding_balance', 'sum'), mean_balance = ('outstanding_balance', 'mean'))
# Out:
#            sum_balance  mean_balance
# education
# primary        8570258   1250.949934
# secondary     26795544   1154.880786
# tertiary      23388697   1758.416435
# unknown        2835183   1526.754443

# %%
pd.set_option('display.max_columns', 100)

# %%
df_banking = df[:20]
df_banking
# Out:
#     age           job   marital  education default  outstanding_balance  \
# 0    58    management   married   tertiary      no                 2143
# 1    44    technician    single  secondary      no                   29
# 2    33  entrepreneur   married  secondary      no                    2
# 3    47   blue-collar   married    unknown      no                 1506
# 4    33       unknown    single    unknown      no                    1
# 5    35    management   married   tertiary      no                  231
# 6    28    management    single   tertiary      no                  447
# 7    42  entrepreneur  divorced   tertiary     yes                    2
# 8    58       retired   married    primary      no                  121
# 9    43    technician    single  secondary      no                  593
# 10   41        admin.  divorced  secondary      no                  270
# 11   29        admin.    single  secondary      no                  390
# ...

# %%
df_banking['average_balance'] = df_banking.groupby('job')['outstanding_balance'].transform('mean')
df_banking
# df_banking.sort_values(by='outstanding_balance',ascending=True)
# Out:
# C:\Users\hp pavilion\AppData\Local\Temp\ipykernel_58572\321182426.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_banking['average_balance'] = df_banking.groupby('job')['outstanding_balance'].transform('mean')
#     age           job   marital  education default  outstanding_balance  \
# 0    58    management   married   tertiary      no                 2143
# 1    44    technician    single  secondary      no                   29
# 2    33  entrepreneur   married  secondary      no                    2
# 3    47   blue-collar   married    unknown      no                 1506
# 4    33       unknown    single    unknown      no                    1
# 5    35    management   married   tertiary      no                  231
# ...

# %%
df_banking['above_below_avg'] = df_banking.groupby('job')['outstanding_balance'].transform(lambda x: x - x.mean())
df_banking
# Out:
# C:\Users\hp pavilion\AppData\Local\Temp\ipykernel_58572\3027172874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_banking['above_below_avg'] = df_banking.groupby('job')['outstanding_balance'].transform(lambda x: x - x.mean())
#     age           job   marital  education default  outstanding_balance  \
# 0    58    management   married   tertiary      no                 2143
# 1    44    technician    single  secondary      no                   29
# 2    33  entrepreneur   married  secondary      no                    2
# 3    47   blue-collar   married    unknown      no                 1506
# 4    33       unknown    single    unknown      no                    1
# ...

# %%
# df_banking['average_house_loan'] = df_banking[(df['housing_loan'] == 'yes') | (df['housing_loan'] == 'no')].groupby('job')['outstanding_balance'].transform('mean')
df_banking['average_house_loan'] = df_banking[df['housing_loan'].isin(['yes', 'no'])].groupby('job')['outstanding_balance'].transform('mean')
df_banking
# Out:
# C:\Users\hp pavilion\AppData\Local\Temp\ipykernel_58572\1100122098.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_banking['average_house_loan'] = df_banking[df['housing_loan'].isin(['yes', 'no'])].groupby('job')['outstanding_balance'].transform('mean')
# C:\Users\hp pavilion\AppData\Local\Temp\ipykernel_58572\1100122098.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_banking['average_house_loan'] = df_banking[df['housing_loan'].isin(['yes', 'no'])].groupby('job')['outstanding_balance'].transform('mean')
#     age           job   marital  education default  outstanding_balance  \
# 0    58    management   married   tertiary      no                 2143
# ...
