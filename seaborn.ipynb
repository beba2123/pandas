# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\hp pavilion\Downloads\real_estate.csv")
df
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico     601.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico     601.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico     795.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico     731.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico     680.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts    1749.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts    1501.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts    1545.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts    1604.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts    1536.0
#
#        house_size prev_sold_date     price
# ...

# %%
housing_filter = df[df['state'].isin(['Puerto Rico', 'Massachusetts', 'New York'])]
sns.barplot(x='state', y = 'price', data = housing_filter, estimator = 'median')
sns.set_palette("grey")
sns.set_context("notebook")
plt.title('Median Housing Prices in Puerto Rico, Massachusetts, and New York')
# Out:
# Text(0.5, 1.0, 'Median Housing Prices in Puerto Rico, Massachusetts, and New York')

# %%
sns.set_palette("muted")
sns.set_context("notebook")
housing_filter = df[df['house_size'] < 10000]
sns.regplot(x= 'house_size', y = 'price', data = housing_filter, line_kws={'color': 'red'})
plt.title('House Size vs. Price')

plt.ticklabel_format(style='plain', axis = 'y')
plt.show()

# %%
iris  = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris, hue = 'species')

# %%
sns.stripplot(data = iris, x = 'species', y = 'sepal_length', hue= 'species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.swarmplot(data= iris, x= 'species', y= 'sepal_length', hue = 'species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(data= iris, x= 'species', y= 'sepal_length', hue = 'species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
df_2 = pd.read_csv(r"C:\Users\hp pavilion\Downloads\smoking.csv")
df_2
# Out:
#       Unnamed: 0  gender  age marital_status highest_qualification  \
# 0              1    Male   38       Divorced      No Qualification
# 1              2  Female   42         Single      No Qualification
# 2              3    Male   40        Married                Degree
# 3              4  Female   40        Married                Degree
# 4              5  Female   39        Married          GCSE/O Level
# ...          ...     ...  ...            ...                   ...
# 1686        1687    Male   22         Single      No Qualification
# 1687        1688  Female   49       Divorced      Other/Sub Degree
# 1688        1689    Male   45        Married      Other/Sub Degree
# 1689        1690  Female   51        Married      No Qualification
# 1690        1691    Male   31        Married                Degree
#
#      nationality ethnicity      gross_income     region smoke  amt_weekends  \
# 0        British     White    2,600 to 5,200  The North    No           NaN
# ...

# %%
smoking = df_2[df_2['smoke'] == 'Yes']  #filtering the data to only include smokers

male_smokers = smoking[smoking['gender'] == 'Male']  #filtering the data to only include male
female_smokers = smoking[smoking['gender'] == 'Female']  #filtering the data to only include female

# %%
fig , ax = plt.subplots(1, 2, figsize = (12, 6)) 
sns.histplot(female_smokers['age'], bins = 20, ax = ax[0], color = 'pink')
sns.histplot(male_smokers['age'], bins=20, ax = ax[1], color = 'blue')
ax[0].set_title('female_smokers - age distribution')
ax[1].set_title('Male_smokers - age distribution')

plt.tight_layout()
plt.show()

# %%
housing_df = pd.read_csv(r"C:\Users\hp pavilion\Downloads\real_estate (1).csv", encoding = 'latin1')
housing_df
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico     601.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico     601.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico     795.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico     731.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico     680.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts    1749.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts    1501.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts    1545.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts    1604.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts    1536.0
#
#        house_size prev_sold_date     price
# ...

# %%
housing_filter = housing_df.drop('zip_code', axis = 1)

housing_filter
# Out:
#          status  bed  bath  acre_lot        city          state  house_size  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico       920.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico      1527.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico       748.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico      1800.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico         NaN
# ...         ...  ...   ...       ...         ...            ...         ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts      2864.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts      1075.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts      1632.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts      1332.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts      1846.0
#
#       prev_sold_date     price
# ...

# %%
numeric_housing_filter = housing_filter.select_dtypes(include=[np.number])
correlation = numeric_housing_filter.corr()
correlation
# Out:
#                  bed      bath  acre_lot  house_size     price
# bed         1.000000  0.715531  0.000135    0.184645  0.199924
# bath        0.715531  1.000000  0.005751    0.226905  0.383401
# acre_lot    0.000135  0.005751  1.000000    0.045852  0.018991
# house_size  0.184645  0.226905  0.045852    1.000000  0.171422
# price       0.199924  0.383401  0.018991    0.171422  1.000000

# %%
sns.heatmap(correlation, annot= True, cmap='coolwarm') #annot = True to display the correlation values on the heatmap
# Out:
# <Axes: >

# %%
pearson_corr = numeric_housing_filter.corr(method='pearson')
pearson_corr
sns.heatmap(pearson_corr, annot= True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
spear_corr = numeric_housing_filter.corr(method='spearman')
spear_corr
# Out:
#                  bed      bath  acre_lot  house_size     price
# bed         1.000000  0.578902 -0.019011    0.662115  0.271416
# bath        0.578902  1.000000  0.235296    0.764824  0.571183
# acre_lot   -0.019011  0.235296  1.000000    0.285697  0.133805
# house_size  0.662115  0.764824  0.285697    1.000000  0.656269
# price       0.271416  0.571183  0.133805    0.656269  1.000000

# %%
sns.heatmap(spear_corr, annot= True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
kende_corr = numeric_housing_filter.corr(method='kendall')
sns.heatmap(kende_corr, annot= True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(3,1, figsize = (8, 6))
sns.heatmap(pearson_corr, annot= True, cmap= 'coolwarm', ax = ax[0])
ax[0].set_title('pearson_corr')
sns.heatmap(spear_corr, annot= True, cmap= 'coolwarm', ax = ax[1])
ax[1].set_title('spear_corr')
sns.heatmap(kende_corr, annot= True, cmap= 'coolwarm', ax = ax[2])
ax[2].set_title('kende_corr')

plt.tight_layout()
