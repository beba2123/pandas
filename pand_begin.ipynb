# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\hp pavilion\Downloads\countries of the world.txt", delimiter = "\t") 
df.head(10)
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %%
df = pd.read_table(r"C:\Users\hp pavilion\Downloads\countries of the world.csv", delimiter=",")  #we use , for separating the columns in the csv file
df.head(10)
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %%
df = pd.read_json(r"C:\Users\hp pavilion\Downloads\json_sample.json") 
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df = pd.read_excel(r"C:\Users\hp pavilion\Downloads\world_population_excel_workbook.xlsx", sheet_name='Sheet1')

# %%
df.tail(10) #to display the last 10 rows in the dataset
# Out:
#      Rank CCA3            Country       Capital
# 224    43  UZB         Uzbekistan      Tashkent
# 225   181  VUT            Vanuatu     Port-Vila
# 226   234  VAT       Vatican City  Vatican City
# 227    51  VEN          Venezuela       Caracas
# 228    16  VNM            Vietnam         Hanoi
# 229   226  WLF  Wallis and Futuna      Mata-Utu
# 230   172  ESH     Western Sahara     El AaiÃºn
# 231    46  YEM              Yemen         Sanaa
# 232    63  ZMB             Zambia        Lusaka
# 233    74  ZWE           Zimbabwe        Harare

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     234 non-null    int64
#  1   CCA3     234 non-null    object
#  2   Country  234 non-null    object
#  3   Capital  234 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 7.4+ KB

# %%
df.iloc[132]
# Out:
# Rank              194
# CCA3              FSM
# Country    Micronesia
# Capital       Palikir
# Name: 132, dtype: object

# %%
df.iloc[120]
# Out:
# Rank                 50
# CCA3                MDG
# Country      Madagascar
# Capital    Antananarivo
# Name: 120, dtype: object

# %%
df[df['Country'].str.contains('Ni')] #to display the rows that contain the word 'Ni' in the country column
# Out:
#      Rank CCA3    Country  Capital
# 147   106  NIC  Nicaragua  Managua
# 148    54  NER      Niger   Niamey
# 149     6  NGA    Nigeria    Abuja
# 150   232  NIU       Niue    Alofi

# %%
specified_country = ['Bangladesh', 'Ghana', 'United_states', 'Nigeria', 'India', 'China', 'Japan', 'South Africa', 'Brazil', 'Canada']
df.loc[df['Country'].isin(specified_country)]
# Out:
#      Rank CCA3       Country    Capital
# 16      8  BGD    Bangladesh      Dhaka
# 27      7  BRA        Brazil   Brasilia
# 35     39  CAN        Canada     Ottawa
# 41      1  CHN         China    Beijing
# 75     47  GHA         Ghana      Accra
# 92      2  IND         India  New Delhi
# 102    11  JPN         Japan      Tokyo
# 149     6  NGA       Nigeria      Abuja
# 193    24  ZAF  South Africa   Pretoria

# %%
df2 = pd.read_excel(r"C:\Users\hp pavilion\Downloads\world_population_excel_workbook.xlsx")
df2 = df2.set_index('Country') #to set the country column as the index
df2.head(20)
# Out:
#                         Rank CCA3              Capital      Continent  \
# Country
# Afghanistan               36  AFG                Kabul           Asia
# Albania                  138  ALB               Tirana         Europe
# Algeria                   34  DZA              Algiers         Africa
# American Samoa           213  ASM            Pago Pago        Oceania
# Andorra                  203  AND     Andorra la Vella         Europe
# Angola                    42  AGO               Luanda         Africa
# Anguilla                 224  AIA           The Valley  North America
# Antigua and Barbuda      201  ATG       Saint Johnâ€™s  North America
# Argentina                 33  ARG         Buenos Aires  South America
# Armenia                  140  ARM              Yerevan           Asia
# Aruba                    198  ABW           Oranjestad  North America
# Australia                 55  AUS             Canberra        Oceania
# ...

# %%
df.filter(items=['Country', 'CCA3'], axis=1) #to display only the country and CCA3 columns
#axis=1 means we are filtering the columns and axis=0 means we are filtering the rows
df.head(10)
# Out:
#    Rank CCA3              Country           Capital
# 0    36  AFG          Afghanistan             Kabul
# 1   138  ALB              Albania            Tirana
# 2    34  DZA              Algeria           Algiers
# 3   213  ASM       American Samoa         Pago Pago
# 4   203  AND              Andorra  Andorra la Vella
# 5    42  AGO               Angola            Luanda
# 6   224  AIA             Anguilla        The Valley
# 7   201  ATG  Antigua and Barbuda    Saint Johnâ€™s
# 8    33  ARG            Argentina      Buenos Aires
# 9   140  ARM              Armenia           Yerevan

# %%
df2.filter(like='United', axis=0) #to display the columns that contain the word 'Country'
# Out:
#                               Rank CCA3           Capital      Continent  \
# Country
# United Arab Emirates            97  ARE         Abu Dhabi           Asia
# United Kingdom                  21  GBR            London         Europe
# United States                    3  USA  Washington, D.C.  North America
# United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#                               2022 Population  2020 Population  \
# Country
# United Arab Emirates                  9441129          9287289
# United Kingdom                       67508936         67059474
# United States                       338289857        335942003
# United States Virgin Islands            99465           100442
#
#                               2015 Population  2010 Population  \
# Country
# United Arab Emirates                  8916899          8481771
# United Kingdom                       65224364         62760039
# ...

# %%
df2.loc['United States Virgin Islands'] #to display the row with the index 'United States'
# Out:
# Rank                                        200
# CCA3                                        VIR
# Capital                        Charlotte Amalie
# Continent                         North America
# 2022 Population                           99465
# 2020 Population                          100442
# 2015 Population                          102803
# 2010 Population                          106142
# 2000 Population                          108185
# 1990 Population                          100685
# 1980 Population                           96640
# 1970 Population                           63446
# Area (kmÂ²)                                 347
# Density (per kmÂ²)                     286.6427
# Growth Rate                              0.9937
# World Population Percentage                 0.0
# Name: United States Virgin Islands, dtype: object

# %%
df2.iloc[5]
# Out:
# Rank                                 42
# CCA3                                AGO
# Capital                          Luanda
# Continent                        Africa
# 2022 Population                35588987
# 2020 Population                33428485
# 2015 Population                28127721
# 2010 Population                23364185
# 2000 Population                16394062
# 1990 Population                11828638
# 1980 Population                 8330047
# 1970 Population                 6029700
# Area (kmÂ²)                     1246700
# Density (per kmÂ²)              28.5466
# Growth Rate                      1.0315
# World Population Percentage        0.45
# Name: Angola, dtype: object

# %%
df2[df2['Rank'] < 10].sort_values('Country', ascending=True)
# Out:
#                Rank CCA3           Capital      Continent  2022 Population  \
# Country
# Bangladesh        8  BGD             Dhaka           Asia        171186372
# Brazil            7  BRA          Brasilia  South America        215313498
# China             1  CHN           Beijing           Asia       1425887337
# India             2  IND         New Delhi           Asia       1417173173
# Indonesia         4  IDN           Jakarta           Asia        275501339
# Nigeria           6  NGA             Abuja         Africa        218541212
# Pakistan          5  PAK         Islamabad           Asia        235824862
# Russia            9  RUS            Moscow         Europe        144713314
# United States     3  USA  Washington, D.C.  North America        338289857
#
#                2020 Population  2015 Population  2010 Population  \
# Country
# Bangladesh           167420951        157830000        148391139
# Brazil               213196304        205188205        196353492
# ...
